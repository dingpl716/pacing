# %%
import pandas as pd

# %%
df = pd.read_csv('.simulate/data/output.csv', parse_dates=['datetime'])

# %%
df.set_index('datetime', inplace=True)

# %%
df['actual_velocity'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='datetime'>
